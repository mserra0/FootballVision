# %% [markdown]
# Utilitzem YOLOv5 per ser la versió amb millor precisió a l'hora de detectar la pilota

# %%
# %pip install -q roboflow

from roboflow import Roboflow

rf = Roboflow(api_key="j7AI0ZCpfsiQWfAc9zhJ")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(8)
dataset = version.download("yolov5")
# Out:
# Note: you may need to restart the kernel to use updated packages.
# loading Roboflow workspace...
# loading Roboflow project...

# %%
dataset.location
# Out:
# 'c:\\Users\\ppugi\\OneDrive - UAB\\UNI\\3º\\2o semestre\\VC\\FA\\training\\football-players-detection-8'

# %%
# # Movem els directoris train, test i valid per evitar problemes amb la biblioteca ultralytics
# import shutil
# shutil.move('football-players-detection-8/train',
#             'football-players-detection-8/football-players-detection-8/train')

# shutil.move('football-players-detection-8/test',
#             'football-players-detection-8/football-players-detection-8/test')

# shutil.move('football-players-detection-8/valid',
#             'football-players-detection-8/football-players-detection-8/valid')

# %% [markdown]
# # Training

# %%
# # Això ho executem a Google Colab
# !yolo task=detect mode=train model=yolov5x.pt data="c:\\Users\\ppugi\\OneDrive - UAB\\UNI\\3º\\2o semestre\\VC\\FA\\training\\football-players-detection-8\\data.yaml" epochs=100 imgsz=640
# Out:
# ^C

# %% [markdown]
# # Resultats de l'entrenament

# %% [markdown]
# ## Yolov5lu

# %%
import cv2
import matplotlib.pyplot as plt

conf_mat = cv2.cvtColor(cv2.imread('../models/yolov5lu/confusion_matrix.png'), cv2.COLOR_BGR2RGB)
f1 = cv2.cvtColor(cv2.imread('../models/yolov5lu/F1_curve.png'), cv2.COLOR_BGR2RGB)
pr = cv2.cvtColor(cv2.imread('../models/yolov5lu/PR_curve.png'), cv2.COLOR_BGR2RGB)
labels = cv2.cvtColor(cv2.imread('../models/yolov5lu/labels_correlogram.jpg'), cv2.COLOR_BGR2RGB)


plt.imshow(conf_mat)
plt.show()
plt.imshow(f1)
plt.show()
plt.imshow(pr)
plt.show()
plt.imshow(labels)
plt.show()
